# %%
# Import libraries

import pandas as pd
import numpy as np
from datapipeline import cropyieldatapipeline
from sklearn.model_selection import train_test_split

# %%
# Import Data

df = pd.read_csv(filepath_or_buffer="../data/crop_yield_train.csv")

# %%
df_mapper, df_updated = cropyieldatapipeline(df)

# %%
df_updated
# Out:
#         id   soil_ph  soil_moisture  avg_temperature  total_rainfall  \
# 0        0  7.831719      37.192725        32.270297      145.627849
# 1        1  6.685905      23.715684        25.852201      599.005355
# 2        2  8.338307      20.481400        18.202587      333.247698
# 3        3  7.214680      42.446504        13.758647      523.610747
# 4        4  5.129093      16.614817        14.444958     1005.931705
# ...    ...       ...            ...              ...             ...
# 4795  4795  5.875831      17.025059        15.661515      878.536336
# 4796  4796  7.303234      16.138273        27.927987      273.478409
# 4797  4797  6.833229      38.105084        24.207628      575.764272
# 4798  4798  5.057801      10.438546        28.840547      946.630937
# 4799  4799  7.602110      12.876269        18.356159      402.219536
#
#       fertilizer_amount  pesticide_usage  sunlight_hours  nitrogen_content  \
# 0            124.830027        11.132490     1911.116978          1.445159
# 1            120.168428        11.846171     2011.488102          0.525983
# 2            270.799112        10.588497     1929.725597          2.996184
# 3             99.013588         1.222238     2231.228584          2.680929
# 4            169.955045         6.350100     2826.831668          1.298629
# ...                 ...              ...             ...               ...
# 4795         158.700801         3.257848     1285.428969          1.113319
# 4796         151.216406         3.962554     1333.150567          1.817108
# 4797         184.379434        13.942368     2009.721557          0.975856
# 4798         109.656487        14.144132     1155.118005          1.542474
# 4799          75.920073         2.463546     1883.719248          1.293796
#
#       phosphorus_content  potassium_content  irrigation_frequency  crop_type  \
# 0               0.698938           1.074339                     3          1
# 1               1.137722           1.718454                     3          1
# 2               1.079680           1.386601                     5          1
# 3               0.764238           0.814746                     5          2
# 4               1.487599           0.910354                     3          2
# ...                  ...                ...                   ...        ...
# 4795            0.202119           0.766489                     6          3
# 4796            1.491216           0.666138                     5          4
# 4797            0.856878           0.586865                     2          3
# 4798            0.446792           0.908985                     5          2
# 4799            0.488368           1.297505                     1          5
#
#       region  season harvest_date  field_id  yield_tpha  harvest_month
# 0          1       1   2021-03-09         1    3.790277              3
# 1          1       2   2021-07-18         2    5.660778              7
# 2          2       3   2021-11-20         3    7.098251             11
# 3          3       3   2021-03-02         4    5.461535              3
# 4          4       3   2021-10-24         5    6.336988             10
# ...      ...     ...          ...       ...         ...            ...
# 4795       3       3   2021-12-23       210    6.546929             12
# 4796       4       3   2021-10-01       243    7.003236             10
# 4797       2       3   2021-08-16       360    5.834223              8
# 4798       2       1   2021-11-15       180    4.761456             11
# 4799       1       1   2021-10-16       215    4.092900             10
#
# [4800 rows x 19 columns]

# %%
# removing id and harvest date as it is not required

# %%
sorted_cols = ['soil_ph', 'soil_moisture', 'avg_temperature', 'total_rainfall',
       'fertilizer_amount', 'pesticide_usage', 'sunlight_hours',
       'nitrogen_content', 'phosphorus_content', 'potassium_content',
       'irrigation_frequency', 'crop_type', 'region', 'season',
       'field_id', 'harvest_month', 'yield_tpha']

# %%
df_fe = df_updated[sorted_cols]

# %%
df_fe
# Out:
#        soil_ph  soil_moisture  avg_temperature  total_rainfall  \
# 0     7.831719      37.192725        32.270297      145.627849
# 1     6.685905      23.715684        25.852201      599.005355
# 2     8.338307      20.481400        18.202587      333.247698
# 3     7.214680      42.446504        13.758647      523.610747
# 4     5.129093      16.614817        14.444958     1005.931705
# ...        ...            ...              ...             ...
# 4795  5.875831      17.025059        15.661515      878.536336
# 4796  7.303234      16.138273        27.927987      273.478409
# 4797  6.833229      38.105084        24.207628      575.764272
# 4798  5.057801      10.438546        28.840547      946.630937
# 4799  7.602110      12.876269        18.356159      402.219536
#
#       fertilizer_amount  pesticide_usage  sunlight_hours  nitrogen_content  \
# 0            124.830027        11.132490     1911.116978          1.445159
# 1            120.168428        11.846171     2011.488102          0.525983
# 2            270.799112        10.588497     1929.725597          2.996184
# 3             99.013588         1.222238     2231.228584          2.680929
# 4            169.955045         6.350100     2826.831668          1.298629
# ...                 ...              ...             ...               ...
# 4795         158.700801         3.257848     1285.428969          1.113319
# 4796         151.216406         3.962554     1333.150567          1.817108
# 4797         184.379434        13.942368     2009.721557          0.975856
# 4798         109.656487        14.144132     1155.118005          1.542474
# 4799          75.920073         2.463546     1883.719248          1.293796
#
#       phosphorus_content  potassium_content  irrigation_frequency  crop_type  \
# 0               0.698938           1.074339                     3          1
# 1               1.137722           1.718454                     3          1
# 2               1.079680           1.386601                     5          1
# 3               0.764238           0.814746                     5          2
# 4               1.487599           0.910354                     3          2
# ...                  ...                ...                   ...        ...
# 4795            0.202119           0.766489                     6          3
# 4796            1.491216           0.666138                     5          4
# 4797            0.856878           0.586865                     2          3
# 4798            0.446792           0.908985                     5          2
# 4799            0.488368           1.297505                     1          5
#
#       region  season  field_id  harvest_month  yield_tpha
# 0          1       1         1              3    3.790277
# 1          1       2         2              7    5.660778
# 2          2       3         3             11    7.098251
# 3          3       3         4              3    5.461535
# 4          4       3         5             10    6.336988
# ...      ...     ...       ...            ...         ...
# 4795       3       3       210             12    6.546929
# 4796       4       3       243             10    7.003236
# 4797       2       3       360              8    5.834223
# 4798       2       1       180             11    4.761456
# 4799       1       1       215             10    4.092900
#
# [4800 rows x 17 columns]

# %% [markdown]
# ### Data split

# %% [markdown]
# * train 60%
# * validation 20%
# * test 20%

# %%
x = df_fe.iloc[:, :-1]
y = df_fe.iloc[:, -1]

# %%
xtrain, xtemp, ytrain, ytemp = train_test_split(x, y, test_size = 0.4, random_state = 30, shuffle = True)

# %%
xvalid, xtest, yvalid, ytest = train_test_split(xtemp, ytemp, test_size = 0.5, random_state = 30, shuffle = True)

# %% [markdown]
# ### Feature Selection

# %% [markdown]
# * we will use baseline models for feature selection
# * models used for feature selection are
#     * lasso regression
#     * random forest

# %%
from sklearn import linear_model
from sklearn.ensemble import RandomForestRegressor

# %%
feat_sel_lasso = linear_model.Lasso(alpha=0.1)
feat_sel_lasso.fit(xtrain, ytrain)
# Out:
# Lasso(alpha=0.1)

# %%
feat_sel_lasso.coef_
# Out:
# array([ 0.00000000e+00,  5.79243486e-03, -6.91403573e-03,  6.96472624e-04,
#         1.23558484e-02, -5.97853430e-02,  4.06915572e-05,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00,  0.00000000e+00,  2.02492822e-05,  0.00000000e+00])

# %%
feat_sel_rf = RandomForestRegressor(random_state=0)
feat_sel_rf.fit(xtrain, ytrain)
# Out:
# RandomForestRegressor(random_state=0)

# %%
feat_sel_rf.feature_importances_
# Out:
# array([0.02428486, 0.02593879, 0.02267853, 0.06441043, 0.62280917,
#        0.08914407, 0.02065902, 0.02400489, 0.02194907, 0.02330856,
#        0.00802719, 0.0074528 , 0.00688549, 0.00523766, 0.0207493 ,
#        0.01246017])

# %%
df_feat_imp = pd.DataFrame(index = df_fe.iloc[:, :-1].columns.to_list())
df_feat_imp["Lasso"] = feat_sel_lasso.coef_
df_feat_imp["RF"] = feat_sel_rf.feature_importances_

# %%
df_feat_imp
# Out:
#                          Lasso        RF
# soil_ph               0.000000  0.024285
# soil_moisture         0.005792  0.025939
# avg_temperature      -0.006914  0.022679
# total_rainfall        0.000696  0.064410
# fertilizer_amount     0.012356  0.622809
# pesticide_usage      -0.059785  0.089144
# sunlight_hours        0.000041  0.020659
# nitrogen_content      0.000000  0.024005
# phosphorus_content    0.000000  0.021949
# potassium_content     0.000000  0.023309
# irrigation_frequency  0.000000  0.008027
# crop_type            -0.000000  0.007453
# region               -0.000000  0.006885
# season                0.000000  0.005238
# field_id              0.000020  0.020749
# harvest_month         0.000000  0.012460

# %%
df_feat_imp[df_feat_imp["Lasso"]>0]
# Out:
#                       Lasso        RF
# soil_moisture      0.005792  0.025939
# total_rainfall     0.000696  0.064410
# fertilizer_amount  0.012356  0.622809
# sunlight_hours     0.000041  0.020659
# field_id           0.000020  0.020749

# %% [markdown]
# * selected features are soil moisture, total rainfall, fertilizer amount, sunlight hours, and filed_id
